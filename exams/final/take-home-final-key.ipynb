# %% [markdown]
# # Data 200: Data Systems for Data Analytics

# %% [markdown]
# # Name:

# %% [markdown]
# # Take Home Final Exam
# <font color='red'>**Due Date:** Dec 20, 5p (T-F 1:30p section) </font> <br>
# <font color='red' style="margin-left: 1.85cm; display: inline-block;">Dec 21, 11:59a (T-F 3p section)</font>
#
# ---
#
# ### **Task**: Scrape data from Goodreads.com 📚
#
# ---
#
# ### **Objective**
# For this exam, you will scrape and analyze data from Goodreads.com. The work is split into two parts, each focusing on different aspects of the data
# 1. **"Best Books" Analysis**: Explore Goodreads' "Best Books" lists for a specific year.
# 2. **Author-Level Analysis**: Study the trends and patterns in the works of a specific author.
#
# ---
#
# ### **Instructions**
#
# #### **Task 1: Best Books**
# You are tasked with analyzing Goodreads' "Best Books" lists for a specific year based on the **first letter of your first name**. For example, if your first name starts with **A–E**, you are assigned to the year **2023**; if it starts with **F–J**, you are assigned to **2022**, and so on:
#
# | Initials | Assigned Year | URL                                              |
# |----------|---------------|---------------------------------------------------------|
# | A–E      | 2023          | [Best Books of 2023](https://www.goodreads.com/list/best_of_year/2023) |
# | F–J      | 2022          | [Best Books of 2022](https://www.goodreads.com/list/best_of_year/2022) |
# | K–O      | 2021          | [Best Books of 2021](https://www.goodreads.com/list/best_of_year/2021) |
# | P–T      | 2020          | [Best Books of 2020](https://www.goodreads.com/list/best_of_year/2020) |
# | U–Z      | 2019          | [Best Books of 2019](https://www.goodreads.com/list/best_of_year/2019) |
#
#
#
# **Your Tasks**:
# 1. Scrape data from the Goodreads "Best Books of [Year]" list:
#    - **URL**: https://www.goodreads.com/list/best_of_year/2023 (replace the year with your assigned year). You can also use the table above.
# 2. Collect the following data for each book:
#    - Title
#    - Publication date (first published)
#    - Author
#    - Genre (if available, and feel free to pick the first genre listed)
#    - Average rating
#    - Number of ratings
#    - Number of pages
#    - Rank
#    - Language (if available)
#    - Number of people who are currently reading (if available)
#    - Number of people who want to read (if available)
# 3. Perform the following analyses:
#    - **Genre ratings**:
#        - Compare average ratings across genres. Which 2-3 genres tends to have the highest ratings? Create a table showing average rating score, and average rank by genre.
#    - **Popularity and ratings**:
#        - Examine whether books with more ratings tend to have higher or lower average scores. Create a scatterplot showing the relationship between the number of ratings and average rating. On the x-axis, you should have **number of ratings**; on the y-axis, you should have **average rating**.
#
# ---
#
# #### **Task 2: Author-Level Analysis**
# You are now tasked with analyzing books by a specific author based on the **first letter of your first name**:
#
# | Your first name initial | Author              | Author Goodreads link                               | Birthday       |
# |----------|---------------------|--------------------------------------------------------------------|----------------|
# | A–E      | Stephen King        | [Stephen King](https://www.goodreads.com/author/list/3389)         | Sep 21, 1947   |
# | F–J      | George R.R. Martin  | [George R.R. Martin](https://www.goodreads.com/author/list/346732) | Sep 20, 1948   |
# | K–O      | Ernest Hemingway    | [Ernest Hemingway](https://www.goodreads.com/author/list/1455)     | Jul 21, 1899   |
# | P–T      | Neil Gaiman         | [Neil Gaiman](https://www.goodreads.com/author/list/1221698)       | Nov 10, 1960   |
# | U–Z      | Nora Roberts        | [Nora Roberts](https://www.goodreads.com/author/list/625)          | Oct 10, 1950   |
#
#
# **Your Tasks**:
# 1. Scrape all books by your assigned author:
#    - Use the link provided for your author.
# 2. Collect the following data for each book:
#    - Title
#    - Publication date (first published)
#    - Author
#    - Genre (if available, and feel free to pick the first genre listed)
#    - Average rating
#    - Number of ratings
#    - Number of pages
#    - Rank (from the books written by the author)
#    - Language (if available)
#    - Number of people who are currently reading (if available)
#    - Number of people who want to read (if available)
# 3. Perform the following analyses:
#    - **Language Distribution**:
#      - How many books has the author published in English? In other languages? Create a table showing the count of books by language.
#    - **Author's Age and Page Count**:
#      - Do authors tend to write longer books as they age? Use the author's birthday to calculate their age at the time of each book's publication. Create a line plot with **author's age** on the x-axis and **page count** on the y-axis.
#    - **Author's Age and Rating**:
#      - For English-only books, create a line plot with **author's age** on the x-axis and **average rating** on the y-axis.
#      - Repeat the analysis including books in languages other than English. Does your interpretation change?
#    - **Pages vs. Ratings**:
#      - Is there a relationship between the number of pages and a book's average rating? Create a scatterplot with **page count** on the x-axis and **average rating** on the y-axis.
#    - **Interest on a book**:
#      - Is there a relationship between the number of people who are currently reading the book and the number of people who left a rating? Create a scatterplot with **number of people who are currently reading** on the x-axis and **number of ratings** on the y-axis. Create a second scatterplot with **average rating** on the y-axis. Do books with more interest tend to receive higher ratings?
#
# ---
#
# ### **Submission Requirements**
# Submit your work as a single `.ipynb` file, along with a copy of it as a `.md` file. The notebook should include:
# 1. **Code**:
#    - Well-documented python code using Selenium for web scraping.
#    - Proper error handling and strategies for dynamic content.
# 2. **Cleaned Data**:
#    - Include the cleaned datasets from both tasks as .csv files. You can upload them in your github repo.
# 3. **Analysis and Report**:
#    - Present your findings using markdown cells, tables, and visualizations you make in python.
#    - Address all questions posed for your assigned tasks.
# 4. **Visualizations**:
#    - Include relevant charts (e.g., bar charts, line plots, scatterplots) to support your conclusions.
#
# ---
#
# ### **Rubric**
#
# | Item                        | Weight |
# |-----------------------------|--------|
# | Code accuracy               | 25%    |
# | Code clarity and annotation | 25%    |
# | Exploratory data analysis   | 25%    |
# | Discussion of findings      | 25%    |
#
# ---
#
# ### **Tips**
# - Make sure to insert time.sleep() right after you request driver to go to a link (before requesting elements). Make sure to wait at least 0.7 second, or even slightly higher if you run into issues.
# - Try-except blocks will be your friend because xpath positions on a page may differ depending on the book and content availability.
#
# ---
#
# ### **Resources**
# - Course notes on Github
# - Selenium documentation: https://www.selenium.dev/documentation/
# - Pandas documentation: https://pandas.pydata.org/docs/
# - Matplotlib documentation: https://matplotlib.org/stable/contents.html
#
# Good luck! 🏁

# %%
from selenium import webdriver
import pandas as pd
import random
import time
pd.set_option('display.max_colwidth', None)

# Task 1: Best Books analysis
# This code grabs book data from the best books page
page_data = pd.DataFrame()
for i in range(1,13):
    driver = webdriver.Chrome()
    driver.get(f'https://www.goodreads.com/list/best_of_year/2023?id=183940.Best_Books_of_2023&page={i}')
    time.sleep(random.uniform(.1,.2))
    try:
        popup = driver.find_element('xpath', '/html/body/div[3]/div/div/div[1]/button/img')
        time.sleep(random.uniform(.1,.2))
        popup.click()
        print("Popup closed.")
    except:
        pass
    
    table_element = driver.find_elements('xpath', "//tr[contains(@itemtype, 'schema.org/Book')]")
    time.sleep(random.uniform(.2,.4))

    table = []
    for i in table_element:
        lines = i.text.split('\n')
        # Filter out any unwanted lines (e.g., "really liked it")
        lines = [line for line in lines if line.strip().lower() != 'really liked it']
        # Now take the first 5 lines of the cleaned list
        row_data = lines[:5]

        # Extract the author's name (between 'by' and '(')
        author_full = row_data[2]  # e.g., 'by Rebecca Yarros (Goodreads Author)'
        author_name = author_full.split('by ')[-1].split(' (')[0].strip()  # Extract author name
        row_data[2] = author_name  # Replace the full 'Author' field with just the name

        # Split the Rating field into Average and Total Ratings
        rating_text = row_data[3]  # e.g., '4.57 avg rating — 2,291,054 ratings'
        avg_rating = rating_text.split(' avg rating')[0]  # Extract '4.57'
        total_ratings = rating_text.split('—')[-1].strip().split(' ratings')[0]  # Extract '2,291,054'
        total_ratings = total_ratings.replace(',', '')  # Remove commas for numerical processing
        row_data[3] = avg_rating  # Replace Rating with Average Rating
        row_data.append(total_ratings)  # Add Total Ratings as a new field

        # Split the Score field into Score and Total Votes
        score_text = row_data[4]  # e.g., 'score: 53,258, and 536 people voted'
        score_value = score_text.split('score: ')[-1].split(', and')[0].strip()  # Extract '53,258'
        total_votes_text = score_text.split('and ')[-1]  # e.g., '536 people voted' or '1 person voted'
        total_votes = total_votes_text.replace(' person voted', '').replace(' people voted', '').strip()  # Remove text
        total_votes = total_votes.replace(',', '')  # Remove commas for numerical processing
    
        score_value = score_value.replace(',', '')  # Remove commas for numerical processing
        row_data[4] = score_value  # Replace Score with the cleaned Score value
        row_data.append(total_votes)  # Add Total Votes as a new field
        
        href = i.find_element('xpath', './/td[3]/a').get_attribute('href')
        row_data.append(href)  # Add href to the row data

        table.append(row_data)

    # Create the DataFrame with the updated columns
    df = pd.DataFrame(table, columns=['Rank', 'Title', 'Author', \
                                      'Average Rating', 'Score', 'Total Ratings', 'Total Votes','url'])
    page_data=pd.concat([df,page_data],axis=0)
    
    driver.quit()
page_data['Rank'] = page_data.Rank.astype('int')
page_data = page_data.sort_values('Rank').reset_index(drop=True)

# %%
page_data
# Out:
#       Rank                                              Title          Author  \
# 0        1                     Fourth Wing (The Empyrean, #1)  Rebecca Yarros
# 1        2                                        Happy Place     Emily Henry
# 2        3                                         Yellowface      R.F. Kuang
# 3        4         Divine Rivals (Letters of Enchantment, #1)    Rebecca Ross
# 4        5                                Love, Theoretically   Ali Hazelwood
# ...    ...                                                ...             ...
# 1152  1153                              You Should Smile More  Anastasia Ryan
# 1153  1154                  When the Farmer Met the City Girl      Jessa Kane
# 1154  1155           Savage Grace (Savages of Kingsworth, #3)   L.M. Harrison
# 1155  1156  Pretend Ring Girl (Seeing Double Twin Sister, #3)      Cassi Hart
# 1156  1157                Demonic Desires (Becoming Lust, #2)     Emilia Rose
#
# ...

# %%
page_data.to_csv('page_data.csv',index=False)

# %%
# This code continues the previous work and grabs more detailed book data by going to each book's url
import time
import random
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# Optional: Run in headless mode
chrome_options = Options()
chrome_options.add_argument("--headless")

books_data = pd.DataFrame()
script_start_time = time.time()  # Record the script's start time

for i in range(len(page_data)):
    driver = webdriver.Chrome(options=chrome_options)
    driver.get(page_data.url[i])
    start_time = time.time()  # Start the timer for this page
    timeout = 5  # Timeout in seconds for the entire page processing

    while True:
        try:
            time.sleep(random.uniform(0.2, 0.4))

            # Check and close the popup if it exists
            try:
                close_button = driver.find_element('xpath', '//button[@aria-label="Close"]')
                if close_button.is_displayed():
                    close_button.click()
            except Exception:
                pass  # Continue if the popup doesn't exist

            # Attempt to expand book details
            try:
                button = driver.find_element('xpath', '//button[@aria-label="Book details and editions"]')
                driver.execute_script("arguments[0].scrollIntoView(true);", button)
                time.sleep(random.uniform(0.2, 0.4))  # Randomized wait for scrolling
                button.click()
            except Exception:
                # If expanding book details fails, default to empty values and continue
                language = ''
                num_pages = ''
                break  # Exit the loop since expanding details failed

            time.sleep(random.uniform(0.2, 0.4))

            # Extract book details
            try:
                edition_details = driver.find_element('xpath', '//*[@class="EditionDetails"]').text
                language = edition_details.split("Language")[-1].split('\n')[1].strip() if "Language" in edition_details else ''
                num_pages = int(edition_details.split(' pages')[0].split('\n')[-1])
            except:
                language = ''
                num_pages = ''

            title = driver.find_element('xpath', '//*[@data-testid="bookTitle"]').text
            publication_date = driver.find_element('xpath', '//*[@data-testid="publicationInfo"]').text
            publication_date = publication_date.replace('First published', '').strip()
            author = driver.find_element('xpath', '//*[@data-testid="name"]').text
            genre = driver.find_element('xpath', '//*[@aria-label="Top genres for this book"]').text.split()[1]
            avg_rating = float(driver.find_element('xpath', '//*[@class="RatingStatistics__rating"]').text)
            num_ratings = driver.find_element('xpath', '//*[@class="RatingStatistics__meta"]').text
            num_ratings = int(num_ratings.split('ratings')[0].strip().replace(',', ''))

            # Handle missing currentlyReadingSignal
            try:
                currently_reading = driver.find_element('xpath', '//*[@data-testid="currentlyReadingSignal"]').text
                currently_reading = currently_reading.split(' people')[0].replace('m', '000000').replace('k', '000').replace('.', '').replace(',', '')
            except:
                currently_reading = ''

            # Handle missing toReadSignal
            try:
                wants = driver.find_element('xpath', '//*[@data-testid="toReadSignal"]').text
                wants = wants.split(' people')[0].replace('m', '000000').replace('k', '000').replace('.', '').replace(',', '')
            except:
                wants = ''

            # Add book data to DataFrame
            book_data = {
                'Title': title,
                'Author': author,
                'Average Rating': avg_rating,
                'Total Ratings': num_ratings,
                'Language': language,
                'Number of Pages': num_pages,
                'Publication Date': publication_date,
                'Genre': genre,
                'Currently Reading': currently_reading,
                'Wants to Read': wants,
                'URL': page_data.url[i]
            }

            books_data = pd.concat([books_data, pd.DataFrame([book_data])], ignore_index=True)

            # Save to CSV dynamically after each scrape
            books_data.to_csv("books_data.csv", index=False)

            # Calculate elapsed time since script started
            elapsed_time_minutes = (time.time() - script_start_time) / 60
            # Print the nth book scraped with title, author, and elapsed time
            print(f"{len(books_data)}th book scraped: '{title}' by {author} | Elapsed time: {elapsed_time_minutes:.2f} minutes")

            break  # Exit the loop if successful

        except Exception as e:
            # Check if timeout is exceeded
            elapsed_time = time.time() - start_time
            if elapsed_time > timeout:
                driver.refresh()
                start_time = time.time()  # Reset the timer after refresh
            else:
                pass  # Suppress error messages and retry

    driver.quit()

# Reset the index of the final DataFrame
books_data.reset_index(drop=True, inplace=True)
# Out:
# 1th book scraped: 'Fourth Wing' by Rebecca Yarros | Elapsed time: 0.06 minutes
# 2th book scraped: 'Happy Place' by Emily Henry | Elapsed time: 0.12 minutes
# 3th book scraped: 'Yellowface' by R.F. Kuang | Elapsed time: 0.42 minutes
# 4th book scraped: 'Divine Rivals' by Rebecca Ross | Elapsed time: 0.49 minutes
# 5th book scraped: 'Love, Theoretically' by Ali Hazelwood | Elapsed time: 0.55 minutes
# 6th book scraped: 'Iron Flame' by Rebecca Yarros | Elapsed time: 0.64 minutes
# 7th book scraped: 'A Curse for True Love' by Stephanie Garber | Elapsed time: 0.73 minutes
# 8th book scraped: 'Tress of the Emerald Sea' by Brandon Sanderson | Elapsed time: 0.82 minutes
# 9th book scraped: 'The Stolen Heir' by Holly Black | Elapsed time: 0.89 minutes
# 10th book scraped: 'Emily Wilde's Encyclopaedia of Faeries' by Heather Fawcett | Elapsed time: 0.98 minutes
# 11th book scraped: 'Hello Beautiful' by Ann Napolitano | Elapsed time: 1.05 minutes
# ...

# %%
books_data
# Out:
#                                   Title          Author  Average Rating  \
# 0                           Fourth Wing  Rebecca Yarros            4.57
# 1                           Happy Place     Emily Henry            3.97
# 2                            Yellowface      R.F. Kuang            3.75
# 3                         Divine Rivals    Rebecca Ross            4.17
# 4                   Love, Theoretically   Ali Hazelwood            4.10
# ...                                 ...             ...             ...
# 1131                         Cleat Cute   Meryl Wilsner            3.75
# 1132                           The RSVP  Lauren Blakely            3.85
# 1133              You Should Smile More  Anastasia Ryan            3.62
# 1134  When the Farmer Met the City Girl      Jessa Kane            3.62
# 1135                  Pretend Ring Girl      Cassi Hart            4.18
#
#       Total Ratings Language Number of Pages    Publication Date    Genre  \
# ...

# %%
# merge with page_data to get the Rank
df1 = page_data[['Rank','url']].merge(books_data, left_on='url',right_on='URL').drop(columns='url')
df1
# Out:
#       Rank                              Title          Author  Average Rating  \
# 0        1                        Fourth Wing  Rebecca Yarros            4.57
# 1        2                        Happy Place     Emily Henry            3.97
# 2        3                         Yellowface      R.F. Kuang            3.75
# 3        4                      Divine Rivals    Rebecca Ross            4.17
# 4        5                Love, Theoretically   Ali Hazelwood            4.10
# ...    ...                                ...             ...             ...
# 1131  1151                         Cleat Cute   Meryl Wilsner            3.75
# 1132  1152                           The RSVP  Lauren Blakely            3.85
# 1133  1153              You Should Smile More  Anastasia Ryan            3.62
# 1134  1154  When the Farmer Met the City Girl      Jessa Kane            3.62
# 1135  1156                  Pretend Ring Girl      Cassi Hart            4.18
#
# ...

# %%
# Best genres:
genres = df1.groupby('Genre').agg({'Rank': ['mean', 'count'],'Average Rating': 'mean'}).reset_index()
genres.columns = ['Genre', 'Avg Rank', 'Count', 'Avg Rating']
genres = genres.sort_values('Avg Rank').reset_index(drop=True)
genres
# Out:
#            Genre     Avg Rank  Count  Avg Rating
# 0        Dragons     1.000000      1    4.570000
# 1      Romantasy     6.000000      1    4.360000
# 2      Mythology   226.875000      8    3.785000
# 3         Sports   372.333333      9    4.015556
# 4          Manga   399.000000      2    4.490000
# 5           Cozy   410.000000      1    4.490000
# 6   Contemporary   410.750000      4    3.980000
# 7         Horror   453.690476     42    3.817143
# 8      Cookbooks   464.500000      2    4.425000
# 9       Business   482.000000      1    4.300000
# 10      Thriller   488.833333     54    3.817593
# 11       Mystery   489.623377     77    3.997662
# 12       Reverse   494.750000     12    4.118333
# 13       Fantasy   498.041667    168    4.033333
# 14        Poetry   499.400000      5    4.196000
# 15      Feminism   516.000000      2    4.155000
# 16     Christian   519.500000      4    4.205000
# 17         Urban   535.166667      6    4.305000
# ...

# %%
# Reviews:
import matplotlib.pyplot as plt
plt.scatter(df1['Total Ratings'],df1['Average Rating'],s=6,c='black')
plt.ylim(2.5,5.1)
plt.xlabel('# of Ratings in millions')
plt.ylabel('Avg Rating')
plt.show()

# %%
# Reviews:
import matplotlib.pyplot as plt
df1_plot = df1[df1['Total Ratings']<100000]
plt.scatter(df1_plot['Total Ratings'],df1_plot['Average Rating'],s=6,c='black')
plt.ylim(2.5,5.1)
plt.xlabel('# of Ratings')
plt.ylabel('Avg Rating')
plt.show()

# %%
# Task 2: Author analysis
# Similar to the previous task, first get book data from the author's page
from selenium import webdriver
import pandas as pd
import random
import time
pd.set_option('display.max_colwidth', None)

page_data = pd.DataFrame()
rank=1
for i in range(1,89):
    driver = webdriver.Chrome()
    driver.get(f'https://www.goodreads.com/author/list/3389.Stephen_King?page={i}')
    time.sleep(random.uniform(.1,.2))
    try:
        popup = driver.find_element('xpath', '/html/body/div[3]/div/div/div[1]/button/img')
        time.sleep(random.uniform(.1,.2))
        popup.click()
        print("Popup closed.")
    except:
        pass
    
    table_element = driver.find_elements('xpath', "//tr[contains(@itemtype, 'schema.org/Book')]")
    time.sleep(random.uniform(.2,.4))

    table = []
    for i in table_element:
        lines = i.text.split('\n')
        # Filter out any unwanted lines (e.g., "really liked it")
        if "rating" not in lines[2].lower():
            del lines[2]  # Remove the third line if it doesn't contain "rating"
        elif "rating" in lines[3].lower(): 
            lines[2] = lines.pop(3)  # Move the fourth line up to replace the third line if needed

        # Now take the first 3 lines of the cleaned list
        row_data = lines[:3]

        # Extract the author's name (between 'by' and '(')
        author_full = row_data[1]  # e.g., 'by Rebecca Yarros (Goodreads Author)'
        author_name = author_full.split('by ')[-1].split(' (')[0].strip()  # Extract author name
        row_data[1] = author_name  # Replace the full 'Author' field with just the name

        # Split the Rating field into Average and Total Ratings
        rating_text = row_data[2]  # e.g., '4.57 avg rating — 2,291,054 ratings'
        avg_rating = rating_text.split(' avg rating')[0]  # Extract '4.57'
        total_ratings = row_data[2].split(' ratings')[0].split('— ')[1]
        total_ratings = total_ratings.replace(',', '')  # Remove commas for numerical processing
        row_data[2] = avg_rating
        row_data.append(total_ratings)  # Add Total Ratings as a new field

        href = i.find_element('xpath', './/td[2]/a').get_attribute('href')
        row_data.append(href)  # Add href to the row data
        row_data.append(rank)
    
        rank+=1

        table.append(row_data)

    # Create the DataFrame with the updated columns
    df = pd.DataFrame(table, columns=['Title', 'Author', \
                                      'Average Rating','Total Ratings','url','Rank'])
    # Optional: have Rank as the first column
    last_col = df.pop(df.columns[-1])
    df.insert(0, last_col.name, last_col)
    
    page_data=pd.concat([df,page_data],axis=0)
    driver.quit()
    
page_data['Rank'] = page_data.Rank.astype('int')
page_data = page_data.sort_values('Rank').reset_index(drop=True)

# %%
page_data
# Out:
#       Rank  \
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ...    ...
# 2615  2616
# 2616  2617
# 2617  2618
# 2618  2619
# 2619  2620
#
#                                                                               Title  \
# 0                                                     The Shining (The Shining, #1)
# 1                                                                                It
# 2                                                                         The Stand
# 3                                                                            Misery
# 4                                                                            Carrie
# ...                                                                             ...
# 2615      The End of the World As We Know It: New Tales of Stephen King's The Stand
# 2616          The End of the World as We Know It: Tales of Stephen King’s The Stand
# ...

# %%
page_data.to_csv('author_page.csv')

# %%
# Continuing with going into each book's url
import time
import random
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from datetime import datetime
pd.set_option('display.float_format', '{:.2f}'.format) # disable scientific notation

# Configure Chrome options for headless mode
chrome_options = Options()
chrome_options.add_argument("--headless")  # Run in headless mode

books_data = pd.DataFrame()
script_start_time = time.time()  # Record the script's start time

for i in range(len(page_data)):
    driver = webdriver.Chrome(options=chrome_options)  # Use the headless configuration
    driver.get(page_data.url[i])
    start_time = time.time()  # Start the timer for this page
    timeout = 5  # Timeout in seconds for the entire page processing

    while True:
        try:
            time.sleep(random.uniform(0.2, 0.4))

            # Check and close the popup if it exists
            try:
                close_button = driver.find_element('xpath', '//button[@aria-label="Close"]')
                if close_button.is_displayed():
                    close_button.click()
            except Exception:
                pass  # Continue if the popup doesn't exist

            # Attempt to expand book details
            try:
                button = driver.find_element('xpath', '//button[@aria-label="Book details and editions"]')
                driver.execute_script("arguments[0].scrollIntoView(true);", button)
                time.sleep(random.uniform(0.2, 0.4))  # Randomized wait for scrolling
                button.click()
            except Exception:
                # If expanding book details fails, default to empty values and continue
                language = ''
                num_pages = ''
                break  # Exit the loop since expanding details failed

            time.sleep(random.uniform(0.2, 0.4))

            # Extract book details
            try:
                edition_details = driver.find_element('xpath', '//*[@class="EditionDetails"]').text
                language = edition_details.split("Language")[-1].split('\n')[1].strip() if "Language" in edition_details else ''
                num_pages = int(edition_details.split(' pages')[0].split('\n')[-1])
            except:
                language = ''
                num_pages = ''

            title = driver.find_element('xpath', '//*[@data-testid="bookTitle"]').text
            publication_date = driver.find_element('xpath', '//*[@data-testid="publicationInfo"]').text
            publication_date = publication_date.replace('First published', '').strip()
            author = driver.find_element('xpath', '//*[@data-testid="name"]').text
            try:
                genre = driver.find_element('xpath', '//*[@aria-label="Top genres for this book"]').text.split()[1]
            except:
                genre=''
            avg_rating = float(driver.find_element('xpath', '//*[@class="RatingStatistics__rating"]').text)
            num_ratings = driver.find_element('xpath', '//*[@class="RatingStatistics__meta"]').text
            num_ratings = int(num_ratings.split('ratings')[0].strip().replace(',', ''))

            # Handle missing currentlyReadingSignal
            try:
                currently_reading = driver.find_element('xpath', '//*[@data-testid="currentlyReadingSignal"]').text
                currently_reading = currently_reading.split(' people')[0].replace('m', '000000').replace('k', '000').replace('.', '').replace(',', '')
            except:
                currently_reading = ''

            # Handle missing toReadSignal
            try:
                wants = driver.find_element('xpath', '//*[@data-testid="toReadSignal"]').text
                wants = wants.split(' people')[0].replace('m', '000000').replace('k', '000').replace('.', '').replace(',', '')
            except:
                wants = ''

            # Add book data to DataFrame
            book_data = {
                'Title': title,
                'Author': author,
                'Average Rating': avg_rating,
                'Total Ratings': num_ratings,
                'Language': language,
                'Number of Pages': num_pages,
                'Publication Date': publication_date,
                'Genre': genre,
                'Currently Reading': currently_reading,
                'Wants to Read': wants,
                'URL': page_data.url[i]
            }

            books_data = pd.concat([books_data, pd.DataFrame([book_data])], ignore_index=True)

            # Save to CSV dynamically after each scrape
            books_data.to_csv("author_books_data.csv", index=False)

            # Calculate elapsed time since script started
            elapsed_time_minutes = (time.time() - script_start_time) / 60
            # Print the nth book scraped with title, author, and elapsed time
            print(f"{len(books_data)}th book scraped: '{title}' by {author} | Elapsed time: {elapsed_time_minutes:.2f} minutes")

            break  # Exit the loop if successful

        except Exception as e:
            # Check if timeout is exceeded
            elapsed_time = time.time() - start_time
            if elapsed_time > timeout:
                driver.refresh()
                start_time = time.time()  # Reset the timer after refresh
            else:
                pass  # Suppress error messages and retry

    driver.quit()

# Reset the index of the final DataFrame
books_data.reset_index(drop=True, inplace=True)
# Out:
# 1th book scraped: 'The Shining' by Stephen King | Elapsed time: 0.06 minutes
# 2th book scraped: 'It' by Stephen King | Elapsed time: 0.13 minutes
# 3th book scraped: 'The Stand' by Stephen King | Elapsed time: 0.21 minutes
# 4th book scraped: 'Misery' by Stephen King | Elapsed time: 0.26 minutes
# 5th book scraped: 'Carrie' by Stephen King | Elapsed time: 0.34 minutes
# 6th book scraped: 'Pet Sematary' by Stephen King | Elapsed time: 0.55 minutes
# 7th book scraped: '11/22/63' by Stephen King | Elapsed time: 0.62 minutes
# 8th book scraped: '’Salem’s Lot' by Stephen King | Elapsed time: 0.74 minutes
# 9th book scraped: 'The Gunslinger' by Stephen King | Elapsed time: 0.87 minutes
# 10th book scraped: 'The Green Mile' by Stephen King | Elapsed time: 1.10 minutes
# 11th book scraped: 'Mr. Mercedes' by Stephen King | Elapsed time: 1.17 minutes
# 12th book scraped: 'The Outsider' by Stephen King | Elapsed time: 1.26 minutes
# ...

# %%
books_data
# Out:
#                                                                               Title  \
# 0                                                                       The Shining
# 1                                                                                It
# 2                                                                         The Stand
# 3                                                                            Misery
# 4                                                                            Carrie
# ...                                                                             ...
# 1996                     After Midnight: Thirteen Chilling Tales for the Dark Hours
# 1997          The End of the World as We Know It: Tales of Stephen King’s The Stand
# 1998  Das Ende der Welt wie wir sie kennen: Geschichten aus Stephen Kings THE STAND
# 1999                               2025 Stephen King Calendar: Meeting Stephen King
# ...

# %%
# some cleaning
books_data['Publication Date'] = books_data['Publication Date'].str.replace('Expected publication','')
books_data['Publication Date'] = books_data['Publication Date'].str.replace('Published ','')
books_data['Currently Reading'] = books_data['Currently Reading'].str.replace('1 person is currently reading','1')
books_data['Currently Reading'] = books_data['Currently Reading'].replace('', np.nan).astype(float)
books_data['Wants to Read'] = books_data['Wants to Read'].replace('', np.nan)
books_data['Number of Pages'] = books_data['Number of Pages'].replace('', np.nan)
books_data['Language'] = books_data['Language'].replace('', np.nan)

# %%
# lanugage distribution
books_data.Language.value_counts()
# Out:
# English                  639
# French                   102
# Spanish; Castilian        81
# Japanese                  64
# German                    59
# Russian                   48
# Dutch; Flemish            25
# Polish                    25
# Bengali                   22
# Italian                   21
# Bulgarian                 13
# Turkish                   12
# Finnish                   12
# Serbian                   12
# Hungarian                 10
# Portuguese                10
# Swedish                    9
# Croatian                   8
# Greek, Modern (1453-)      8
# Arabic                     8
# Chinese                    7
# Danish                     7
# Icelandic                  7
# Romanian                   6
# Georgian                   6
# Lithuanian                 5
# Czech                      5
# Norwegian                  5
# Korean                     4
# Thai                       3
# Persian                    3
# Multiple languages         2
# ...

# %%
# author's age and page count
books_data['Publication Date'] = pd.to_datetime(books_data['Publication Date'],errors='coerce')
books_data['Stephen King Birthday'] = datetime(1947, 9, 21)

# Calculate the difference in years
books_data['age'] = (
    books_data['Publication Date'] - books_data['Stephen King Birthday']
).dt.days // 365

to_plot = books_data[(books_data.age>26)&(books_data.age<78)]
to_plot.loc[to_plot['Number of Pages'] > 10000, 'Number of Pages'] = np.nan
to_plot = to_plot.groupby('age').agg({'Number of Pages':'mean','age':'count'}).rename(columns={'age':'count'})\
.reset_index()

plt.plot(to_plot['age'],to_plot['Number of Pages'])
plt.xlim(25,80)
plt.xlabel("Stephen King's age")
plt.ylabel('# of pages')
plt.show()

# %%
# Age and Average rating

# Plot for all books
to_plot_all = books_data[(books_data.age > 26) & (books_data.age < 78)]
to_plot_all.loc[to_plot_all['Average Rating'] == 0, 'Average Rating'] = np.nan
to_plot_all = to_plot_all.groupby('age').agg({'Average Rating': 'mean', 'age': 'count'})\
.rename(columns={'age': 'count'}).reset_index()

# Plot for English books
to_plot_english = books_data[(books_data.age > 26) & (books_data.age < 78)]
to_plot_english = to_plot_english[to_plot_english.Language == 'English']
to_plot_english.loc[to_plot_english['Average Rating'] == 0, 'Average Rating'] = np.nan
to_plot_english = to_plot_english.groupby('age').agg({'Average Rating': 'mean', 'age': 'count'})\
.rename(columns={'age': 'count'}).reset_index()

# Plot for translated books
to_plot_translated = books_data[(books_data.age > 26) & (books_data.age < 78)]
to_plot_translated = to_plot_translated[(to_plot_translated.Language != 'English') & \
                                        (to_plot_translated.Language.notna())]
to_plot_translated.loc[to_plot_translated['Average Rating'] == 0, 'Average Rating'] = np.nan
to_plot_translated = to_plot_translated.groupby('age').agg({'Average Rating': 'mean', 'age': 'count'})\
.rename(columns={'age': 'count'}).reset_index()

# Optional: Plot all three on the same graph
plt.plot(to_plot_all['age'], to_plot_all['Average Rating'], label='All Books',color='black')
plt.plot(to_plot_english['age'], to_plot_english['Average Rating'], label='English Books')
plt.plot(to_plot_translated['age'], to_plot_translated['Average Rating'], label='Translated Books')
plt.xlim(25, 80)
plt.ylim(3, 5)
plt.xlabel("Stephen King's age")
plt.ylabel('Avg Rating')
plt.legend()
plt.show()

# %%
# Page count and Average rating
to_plot = books_data[(books_data.age > 26) & (books_data.age < 78)]
to_plot.loc[to_plot['Number of Pages'] > 10000, 'Number of Pages'] = np.nan
to_plot.loc[to_plot['Average Rating'] == 0, 'Average Rating'] = np.nan

plt.scatter(to_plot['Number of Pages'],to_plot['Average Rating'],s=8)
plt.xlabel('# of pages')
plt.ylabel('Avg rating')
plt.show()

to_plot = to_plot[to_plot['Number of Pages']<1200]
plt.scatter(to_plot['Number of Pages'],to_plot['Average Rating'],s=8)
plt.xlabel('# of pages')
plt.ylabel('Avg rating')
plt.show()

# %%
# Number of people currently reading the book and number of ratings left
to_plot = books_data[(books_data.age > 26) & (books_data.age < 78)]
to_plot.loc[to_plot['Average Rating'] == 0, 'Average Rating'] = np.nan

plt.scatter(to_plot['Currently Reading'],to_plot['Total Ratings'],s=8)
plt.xlabel('# of people currently reading')
plt.ylabel('# of ratings')
plt.show()

to_plot = to_plot[to_plot['Currently Reading']<20000]
plt.scatter(to_plot['Currently Reading'],to_plot['Total Ratings'],s=8)
plt.xlabel('# of people currently reading')
plt.ylabel('# of ratings')
plt.xlim(-1000,20000)
plt.show()
