# %%
import pandas as pd
import requests

# %%
apiKey = 'Paste Your API Key Here'
# You can find your api key under Developer Dashboard on the left, and 🗝️Authentication

# %%
url = "https://api.themoviedb.org/3/discover/movie?&page=1`&sort_by=vote_average.desc&primary_release_year=2024&vote_count.gte=1000"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer " + apiKey
}

response = requests.get(url, headers=headers)

out = response.json()

pd.DataFrame.from_dict(out['results'])
# Out:
#     adult                     backdrop_path                genre_ids       id  \
# 0   False  /mQZJoIhTEkNhCYAqcHrQqhENLdu.jpg         [16, 878, 10751]  1184918
# 1   False  /xOMo8BRK7PfcJv9JCnx7s5hj0PX.jpg                [878, 12]   693134
# 2   False  /dvBCdCohwWbsP5qAaglOXagDMtk.jpg            [28, 35, 878]   533535
# 3   False  /p5ozvmdgsmbWe0H8Xk7Rc8SCwAB.jpg  [16, 12, 35, 18, 10751]  1022789
# 4   False  /wNAhuOZ3Zf84jCIlrcI6JhgmY5q.jpg            [28, 878, 12]   786892
# 5   False  /tncbMvfV0V07UZozXdBEq4Wu9HH.jpg                 [28, 35]   573435
# 6   False  /sI6uCeF8mUlZx22mFfHSi9W3XQ9.jpg          [10749, 18, 35]   843527
# 7   False  /4MCKNAc6AbWjEsM2h9Xc29owo4z.jpg             [80, 28, 53]   866398
# 8   False  /oBIQDKcqNxKckjugtmzpIIOgoc4.jpg          [28, 10752, 53]   969492
# 9   False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg            [18, 27, 878]   933260
# 10  False  /nxxCPRGTzxUH8SFMrIsvMmdxHti.jpg          [35, 14, 10751]   639720
# ...

# %%
# multi-year API requests
apiKey = 'eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIzYmU3ZmNkNDBjZmMwMGEyZmM5MjEwNGI1ODJkMWJhMiIsIm5iZiI6MTY2ODAzMTY0Mi4yNDYsInN1YiI6IjYzNmMyNDlhZmZkNDRkMDBkY2JjM2IzZiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.uY_S0SgLhEzCiaVjnQRebLECgpmGJ5crUePr7gfUVEA'

headers = {
        "accept": "application/json",
        "Authorization": "Bearer " + apiKey
}

def getmovie(year):
    url = f"https://api.themoviedb.org/3/discover/movie?&page=1`&sort_by=vote_average.desc&primary_release_year={year}&vote_count.gte=1000"
    response = requests.get(url, headers=headers)
    out = response.json()
    return(pd.DataFrame.from_dict(out['results']))

# %%
df = []
for i in range(1950,2025):
    print(i)
    df.append(getmovie(i))
# Out:
# 1950
# 1951
# 1952
# 1953
# 1954
# 1955
# 1956
# 1957
# 1958
# 1959
# 1960
# 1961
# 1962
# 1963
# 1964
# 1965
# 1966
# 1967
# 1968
# 1969
# 1970
# 1971
# 1972
# 1973
# 1974
# 1975
# 1976
# 1977
# 1978
# 1979
# 1980
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022
# 2023
# 2024

# %%
df_out = pd.concat(df).reset_index(drop=True)

# %%
df_out['year']=df_out.release_date.str[0:4]

# %%
to_analyze = df_out.groupby('year').mean().reset_index()
to_analyze
# Out:
# /var/folders/cx/rmycmzb94blbhzklstnxrkyc0000gn/T/ipykernel_31975/479033218.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   to_analyze = df_out.groupby('year').mean().reset_index()
#     year  adult             id  popularity  video  vote_average   vote_count
# 0   1950    0.0    3269.000000   32.699000    0.0      7.887500  3250.500000
# 1   1951    0.0    3616.750000   31.199250    0.0      7.494000  2489.000000
# 2   1952    0.0    1647.333333   21.686667    0.0      8.066667  1891.333333
# 3   1953    0.0    9881.666667   24.268667    0.0      7.766667  2815.000000
# 4   1954    0.0    1518.833333   25.124667    0.0      8.028167  2763.000000
# ..   ...    ...            ...         ...    ...           ...          ...
# ...

# %%
to_analyze['year'] = to_analyze.year.astype('int')

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot(to_analyze.year,to_analyze.vote_average)
plt.xticks(range(1950,2024,10))
plt.ylim(5,10)
#plt.xlim(2010,2025)
plt.show()
